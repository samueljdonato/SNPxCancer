# %%
# notebooks/01_test_vcf_parser.ipynb

import sys
sys.path.append("../scripts")

from vcf_parser import load_vcf_subset

# Example data path (edit as needed)
vcf_file = "../data/raw/clinvar.vcf"

# Test with known cancer-associated SNPs (placeholder)
cancer_rsids = ["rs28934578", "rs121913529", "rs61764370"]

# Load and inspect
df = load_vcf_subset(vcf_file, cancer_rsids)
if df is not None:
    display(df.head())
# Out:
# Loading VCF from ../data/raw/clinvar.vcf ...
# ⚠️ No matching SNPs found in the VCF.
